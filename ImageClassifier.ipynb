# %% [markdown]
# # Cats and Dogs image classifier

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import img_to_array

# Load the VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
def extract_features(folder):
    features = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (224, 224))  # Resize to match VGG16 input size
        img_array = img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)
        feature = base_model.predict(img_array)
        features.append(feature.flatten())
    return np.array(features)

# %%
# Paths to your dataset
train_cats_path = 'C:/DATA/images/train/cats'
train_dogs_path = 'C:/DATA/images/train/dogs'
test_cats_path = 'C:/DATA/images/test/cats'
test_dogs_path = 'C:/DATA/images/test/dogs'

# %%
# Extract features
train_cats_features = extract_features(train_cats_path)
train_dogs_features = extract_features(train_dogs_path)
X_train = np.vstack([train_cats_features, train_dogs_features])
y_train = np.array([0] * len(train_cats_features) + [1] * len(train_dogs_features))

test_cats_features = extract_features(test_cats_path)
test_dogs_features = extract_features(test_dogs_path)
X_test = np.vstack([test_cats_features, test_dogs_features])
y_test = np.array([0] * len(test_cats_features) + [1] * len(test_dogs_features))

# Split the data
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 856ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# ...

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# Train the SVM model
clf = SVC(kernel='linear', probability=True)  # Use probability=True for plotting curves
clf.fit(X_train, y_train)

# Validate the model
y_val_pred = clf.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))

# Test the model
y_test_pred = clf.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
# Out:
# Validation Accuracy: 0.9375
# Test Accuracy: 0.9071428571428571

# %%
def plot_confusion_matrix(cm, classes):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

def plot_roc_curve(y_true, y_scores):
    from sklearn.metrics import roc_curve, auc
    fpr, tpr, _ = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Confusion Matrix
cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm, classes=['Cat', 'Dog'])
# ROC Curve
y_test_prob = clf.decision_function(X_test)
plot_roc_curve(y_test, y_test_prob)
